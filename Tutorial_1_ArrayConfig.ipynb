# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook

# %%
from ctadiv import *
from ctadiv.ArrayConfig import *

# %% [markdown]
# ## Load a CTA configuration

# %%
# Note that if the radius is in meters, 
# you can set LoadConfig(file, radius="meters")
# defalut is in degrees

array = LoadConfig("./config/layout-3AL4M15-5.txt")

# %% [markdown]
# ## Check configuration table

# %%
array.table
# Out:
# <Table length=19>
#   id     x       y       z       az   ...   p_x     p_y     p_z    d_tel
#          m       m       m      rad   ...                            m
# int64 float64 float64 float64 float64 ... float64 float64 float64 float64
# ----- ------- ------- ------- ------- ... ------- ------- ------- -------
#     1  -70.04   -7.23    54.0   0.000 ...   1.000  -0.000   0.000   34.63
#     2  -34.37  110.98    43.0   0.000 ...   1.000  -0.000   0.000   94.18
#     3   76.18   95.34    39.7   0.000 ...   1.000  -0.000   0.000  166.98
#     4   31.81   -19.7    43.0   0.000 ...   1.000  -0.000   0.000  117.20
#     5 -210.65   50.51    61.3   0.000 ...   1.000  -0.000   0.000  137.60
#     6 -179.06  223.02    42.1   0.000 ...   1.000  -0.000   0.000  222.09
#     7   27.96  243.56    23.2   0.000 ...   1.000  -0.000   0.000  241.86
#     8  176.27   127.9    19.3   0.000 ...   1.000  -0.000   0.000  273.21
#     9  124.21 -134.56    39.6   0.000 ...   1.000  -0.000   0.000  256.94
#    10  -74.73 -144.16    53.2   0.000 ...   1.000  -0.000   0.000  170.79
#    11 -214.79 -122.52    74.1   0.000 ...   1.000  -0.000   0.000  205.43
#    12  -98.11  376.45    20.7   0.000 ...   1.000  -0.000   0.000  351.74
#    13   21.08 -307.61    73.3   0.000 ...   1.000  -0.000   0.000  348.76
#    14  -196.4 -290.24    88.1   0.000 ...   1.000  -0.000   0.000  341.27
#    15     0.9   44.85    40.0   0.000 ...   1.000  -0.000   0.000   79.27
#    16 -302.85   384.6     3.3   0.000 ...   1.000  -0.000   0.000  426.47
#    17  -345.0   175.0    69.0   0.000 ...   1.000  -0.000   0.000  308.14
#    18 -374.99  -33.39    92.6   0.000 ...   1.000  -0.000   0.000  308.33
#    19  204.28 -267.84    53.0   0.000 ...   1.000  -0.000   0.000  406.31

# %% [markdown]
# ## Activate the divergent pointing mode

# %%
array.divergent_pointing(div = 0.0043, az = 180, alt = 70)

#array.set_pointing_coord(az=180, alt=70)
#array.divergent_pointing(0.01)

# %% [markdown]
# ## Check the average of the telescope array location

# %%
array.calc_mean(["x", "y", "z"])
# Out:
# array([-75.7       ,  26.57684211,  49.07894737])

# %% [markdown]
# ## Check the average of the telescope pointing vector

# %%
array.calc_mean(["p_x", "p_y", "p_z"])
# Out:
# array([-3.42399044e-01, -1.26926972e-05,  9.39469241e-01])

# %% [markdown]
# ## Check the hyper field of view (hFoV)

# %%
array.hFoV(m_cut=3)
# Out:
# <Quantity 75.53508452 deg2>

# %% [markdown]
# ## Convert (radians or meters) to degrees

# %%
array.table.units = "deg"
array.table
# Out:
# <Table length=19>
#   id     x       y       z       az   ...   p_x     p_y     p_z    d_tel
#          m       m       m      deg   ...                            m
# int64 float64 float64 float64 float64 ... float64 float64 float64 float64
# ----- ------- ------- ------- ------- ... ------- ------- ------- -------
#     1  -70.04   -7.23    54.0 179.756 ...  -0.342  -0.001   0.940   34.63
#     2  -34.37  110.98    43.0 180.611 ...  -0.341   0.004   0.940   94.18
#     3   76.18   95.34    39.7 180.505 ...  -0.336   0.003   0.942  166.98
#     4   31.81   -19.7    43.0 179.662 ...  -0.338  -0.002   0.941  117.20
#     5 -210.65   50.51    61.3 180.170 ...  -0.347   0.001   0.938  137.60
#     6 -179.06  223.02    42.1 181.397 ...  -0.346   0.008   0.938  222.09
#     7   27.96  243.56    23.2 181.583 ...  -0.338   0.009   0.941  241.86
#     8  176.27   127.9    19.3 180.754 ...  -0.333   0.004   0.943  273.21
#     9  124.21 -134.56    39.6 178.809 ...  -0.335  -0.007   0.942  256.94
#    10  -74.73 -144.16    53.2 178.770 ...  -0.342  -0.007   0.940  170.79
#    11 -214.79 -122.52    74.1 178.945 ...  -0.347  -0.006   0.938  205.43
#    12  -98.11  376.45    20.7 182.512 ...  -0.343   0.015   0.939  351.74
#    13   21.08 -307.61    73.3 177.565 ...  -0.338  -0.014   0.941  348.76
#    14  -196.4 -290.24    88.1 177.753 ...  -0.346  -0.014   0.938  341.27
#    15     0.9   44.85    40.0 180.133 ...  -0.339   0.001   0.941   79.27
#    16 -302.85   384.6     3.3 182.506 ...  -0.351   0.015   0.936  426.47
#    17  -345.0   175.0    69.0 181.034 ...  -0.352   0.006   0.936  308.14
#    18 -374.99  -33.39    92.6 179.584 ...  -0.353  -0.003   0.936  308.33
#    19  204.28 -267.84    53.0 177.803 ...  -0.331  -0.013   0.943  406.31

# %% [markdown]
# ## Check the ICRS coordinate of the pointing

# %%
array.frame.info
array.get_pointing_coord(icrs=True)
# Out:
# Observer         :  CTA North
# Location         :  Roque de los Muchachos , (5327.28509212, -1718.7771125, 3051.78673275) km
# Observation time :  2022-02-20T16:59:17.695
# <SkyCoord (ICRS): (ra, dec) in deg
#     [(27.34677332, 8.67042003), (27.05191185, 8.74347791),
#      (27.09026271, 8.99749019), (27.37791928, 8.8973983 ),
#      (27.20340039, 8.3516845 ), (26.77420906, 8.40748871),
#      (26.71994995, 8.87092346), (27.00790004, 9.21371902),
#      (27.66546827, 9.10956613), (27.68794   , 8.65898689),
#      (27.6329449 , 8.35329465), (26.39031033, 8.57544641),
#      (28.09592945, 8.89752185), (28.04906657, 8.40735365),
#      (27.21676476, 8.82298629), (26.37367348, 8.08774138),
#      (26.89563006, 8.04885639), (27.41144229, 8.00108664),
#      (27.99973336, 9.30705003)]>

# %% [markdown]
# ## Grouping telescopes

# %%
group = {"LST": [1,2,3,4],
        "MST": np.arange(5, 20)}

sub_groups={'1': [5,17,18], 
            '2': [10,11,14],
            '3': [7,15,8], 
            '4': [9,13,19],
            '5': [6,12,16],
            'LST': [1,2,3,4]}

array.display("xz", group=group)
# Out:
# <img src="data:image/png;base64,..." width="800">
# <AxesSubplot:xlabel='x [m]', ylabel='z [m]'>

# %% [markdown]
# ### Subarray barycenter

# %%
from ctadiv.ArrayConfig import visualization as visual

# %%
groupped_table, labels = array.group_by(sub_groups)
visual.display_barycenter(groupped_table, proj="xz", labels=labels)
# Out:
# <img src="data:image/png;base64,..." width="800">
# No handles with labels found to put in legend.
# <AxesSubplot:xlabel='x [m]', ylabel='z [m]'>

# %% [markdown]
# ## Export cfg file

# %%
array.export_cfg(verbose=True)
# Out:
# #ifndef TELESCOPE
#
# #  define TELESCOPE 0
#
# #endif
#
# #if TELESCOPE == 0
#
#    TELESCOPE_THETA=20.00
#
#    TELESCOPE_PHI=180.00
#
#
#
# % Global and default configuration for things missing in telescope-specific config.
#
# #  include <CTA-ULTRA6-LST.cfg>
#
#
#
# #elif TELESCOPE == 1
#
# #  include <CTA-ULTRA6-LST.cfg>
#
#    TELESCOPE_THETA=19.98
#
#    TELESCOPE_PHI=179.76
#
#
#
# #elif TELESCOPE == 2
#
# #  include <CTA-ULTRA6-LST.cfg>
#
#    TELESCOPE_THETA=19.91
#
#    TELESCOPE_PHI=180.61
#
#
#
# #elif TELESCOPE == 3
#
# #  include <CTA-ULTRA6-LST.cfg>
#
#    TELESCOPE_THETA=19.66
#
#    TELESCOPE_PHI=180.50
#
#
#
# #elif TELESCOPE == 4
#
# #  include <CTA-ULTRA6-LST.cfg>
#
#    TELESCOPE_THETA=19.76
#
#    TELESCOPE_PHI=179.66
#
#
#
# #elif TELESCOPE == 5
#
# #  include <CTA-ULTRA6-MST-NectarCam.cfg>
#
#    TELESCOPE_THETA=20.30
#
#    TELESCOPE_PHI=180.17
#
#
#
# #elif TELESCOPE == 6
#
# #  include <CTA-ULTRA6-MST-NectarCam.cfg>
#
#    TELESCOPE_THETA=20.25
#
#    TELESCOPE_PHI=181.40
#
#
#
# #elif TELESCOPE == 7
#
# #  include <CTA-ULTRA6-MST-NectarCam.cfg>
#
#    TELESCOPE_THETA=19.79
#
#    TELESCOPE_PHI=181.58
#
#
#
# #elif TELESCOPE == 8
#
# #  include <CTA-ULTRA6-MST-NectarCam.cfg>
#
#    TELESCOPE_THETA=19.44
#
#    TELESCOPE_PHI=180.75
#
#
#
# #elif TELESCOPE == 9
#
# #  include <CTA-ULTRA6-MST-NectarCam.cfg>
#
#    TELESCOPE_THETA=19.55
#
#    TELESCOPE_PHI=178.81
#
#
#
# #elif TELESCOPE == 10
#
# #  include <CTA-ULTRA6-MST-NectarCam.cfg>
#
#    TELESCOPE_THETA=20.00
#
#    TELESCOPE_PHI=178.77
#
#
#
# #elif TELESCOPE == 11
#
# #  include <CTA-ULTRA6-MST-NectarCam.cfg>
#
#    TELESCOPE_THETA=20.30
#
#    TELESCOPE_PHI=178.94
#
#
#
# #elif TELESCOPE == 12
#
# #  include <CTA-ULTRA6-MST-NectarCam.cfg>
#
#    TELESCOPE_THETA=20.09
#
#    TELESCOPE_PHI=182.51
#
#
#
# #elif TELESCOPE == 13
#
# #  include <CTA-ULTRA6-MST-NectarCam.cfg>
#
#    TELESCOPE_THETA=19.77
#
#    TELESCOPE_PHI=177.56
#
#
#
# #elif TELESCOPE == 14
#
# #  include <CTA-ULTRA6-MST-NectarCam.cfg>
#
#    TELESCOPE_THETA=20.26
#
#    TELESCOPE_PHI=177.75
#
#
#
# #elif TELESCOPE == 15
#
# #  include <CTA-ULTRA6-MST-NectarCam.cfg>
#
#    TELESCOPE_THETA=19.83
#
#    TELESCOPE_PHI=180.13
#
#
#
# #elif TELESCOPE == 16
#
# #  include <CTA-ULTRA6-MST-NectarCam.cfg>
#
#    TELESCOPE_THETA=20.58
#
#    TELESCOPE_PHI=182.51
#
#
#
# #elif TELESCOPE == 17
#
# #  include <CTA-ULTRA6-MST-NectarCam.cfg>
#
#    TELESCOPE_THETA=20.61
#
#    TELESCOPE_PHI=181.03
#
#
#
# #elif TELESCOPE == 18
#
# #  include <CTA-ULTRA6-MST-NectarCam.cfg>
#
#    TELESCOPE_THETA=20.65
#
#    TELESCOPE_PHI=179.58
#
#
#
# #elif TELESCOPE == 19
#
# #  include <CTA-ULTRA6-MST-NectarCam.cfg>
#
#    TELESCOPE_THETA=19.36
#
#    TELESCOPE_PHI=177.80
#
# #else
#
#    Error Invalid telescope for CTA-ULTRA6 La Palma configuration.
#
# #endif
#
# trigger_telescopes = 2 % In contrast to Prod-3 South we apply loose stereo trigger immediately
#
# array_trigger = array_trigger_ultra6_diver-test.dat

# %% [markdown]
# ## Display the telescope pointing

# %% [markdown]
# ### Simple display

# %%
# 1D
array.display("y")
# Out:
# <img src="data:image/png;base64,..." width="800">
# <AxesSubplot:xlabel='y [m]'>

# %%
# 2D
array.display("xz", group=group)
# Out:
# <img src="data:image/png;base64,..." width="800">
# <AxesSubplot:xlabel='x [m]', ylabel='z [m]'>

# %%
# 3D
array.display("xyz", group=group)
# Out:
# <img src="data:image/png;base64,..." width="800">
# <Axes3DSubplot:xlabel='x [m]', ylabel='y [m]'>

# %%
# Skymap
array.display(skymap=True,projection='x')
# Out:
# <img src="data:image/png;base64,..." width="800">
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [20], in <module>
#       1 # Skymap
# ----> 2 array.display(skymap=True,projection='x')
#
# File ~/cta/Divergent-Pointing-my-version/ctadiv/ArrayConfig/telescope.py:609, in Array.display(self, projection, ax, group, **kwargs)
#     606             proj.append(axis)
#     608 if len(proj) == 1:
# --> 609     ax = visual.display_1d(tel_group, proj, ax=ax, labels=labels, **kwargs)
#     610 elif len(proj) == 2:
#     611     ax = visual.display_2d(tel_group, proj, ax=ax, labels=labels, **kwargs)
#
# File ~/cta/Divergent-Pointing-my-version/ctadiv/ArrayConfig/visualization.py:41, in display_1d(table, proj, ax, labels, **kwargs)
#      39     c = COLORS(i)
#      40     for val in tels[proj[0]]:
# ---> 41         ax.axvline(val, label=label, color=c, **kwargs)
#      42         label='_nolegend_'
#      44 ax.axvline(xb, color="r", label='barycenter', **kwargs)
#
# File ~/miniconda3/envs/divergent/lib/python3.9/site-packages/matplotlib/axes/_axes.py:790, in Axes.axvline(self, x, ymin, ymax, **kwargs)
#     787 scalex = (xx < xmin) or (xx > xmax)
#     789 trans = self.get_xaxis_transform(which='grid')
# --> 790 l = mlines.Line2D([x, x], [ymin, ymax], transform=trans, **kwargs)
#     791 self.add_line(l)
#     792 self._request_autoscale_view(scalex=scalex, scaley=False)
#
# File ~/miniconda3/envs/divergent/lib/python3.9/site-packages/matplotlib/lines.py:397, in Line2D.__init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     393 self.set_markeredgewidth(markeredgewidth)
#     395 # update kwargs before updating data to give the caller a
#     396 # chance to init axes (and hence unit support)
# --> 397 self.update(kwargs)
#     398 self.pickradius = pickradius
#     399 self.ind_offset = 0
#
# File ~/miniconda3/envs/divergent/lib/python3.9/site-packages/matplotlib/artist.py:1062, in Artist.update(self, props)
#    1060             func = getattr(self, f"set_{k}", None)
#    1061             if not callable(func):
# -> 1062                 raise AttributeError(f"{type(self).__name__!r} object "
#    1063                                      f"has no property {k!r}")
#    1064             ret.append(func(v))
#    1065 if ret:
#
# AttributeError: 'Line2D' object has no property 'skymap'

# %%
# Multiplicity plot
array.multiplicity_plot().

# %%
# Multiplicity plot
array.skymap_polar()

# %% [markdown]
# ## Advanced display

# %% [markdown]
# ### Interactive

# %%
from ctadiv.ArrayConfig.visualization import *

# %%
new_array = interactive_polar(array, group=group, overwrite=False)

# %%
interactive_multiplicity(array, overwrite=True)

# %%
interactive_barycenter(array, "xy", group=sub_groups)
