# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook

# %%
from ctadiv import *
from ctadiv.ArrayConfig import *

# %% [markdown]
# ## Load a CTA configuration

# %%
# Note that if the radius is in meters, 
# you can set LoadConfig(file, radius="meters")
# defalut is in degrees

array = LoadConfig("./config/layout-3AL4M15-5.txt")

# %% [markdown]
# ## Check configuration table

# %%
array.table
# Out:
# <Table length=19>
#   id     x       y       z       az     alt      zn    focal   radius   fov     p_x     p_y     p_z    d_tel
#          m       m       m      rad     rad     rad      m       m      rad2                             m
# int64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64
# ----- ------- ------- ------- ------- ------- ------- ------- ------- ------- ------- ------- ------- -------
#     1  -70.04   -7.23    54.0   0.000   0.000   1.571  28.000   1.051   0.004   1.000  -0.000   0.000   34.63
#     2  -34.37  110.98    43.0   0.000   0.000   1.571  28.000   1.051   0.004   1.000  -0.000   0.000   94.18
#     3   76.18   95.34    39.7   0.000   0.000   1.571  28.000   1.051   0.004   1.000  -0.000   0.000  166.98
#     4   31.81   -19.7    43.0   0.000   0.000   1.571  28.000   1.051   0.004   1.000  -0.000   0.000  117.20
#     5 -210.65   50.51    61.3   0.000   0.000   1.571  16.000   1.077   0.014   1.000  -0.000   0.000  137.60
#     6 -179.06  223.02    42.1   0.000   0.000   1.571  16.000   1.077   0.014   1.000  -0.000   0.000  222.09
#     7   27.96  243.56    23.2   0.000   0.000   1.571  16.000   1.077   0.014   1.000  -0.000   0.000  241.86
#     8  176.27   127.9    19.3   0.000   0.000   1.571  16.000   1.077   0.014   1.000  -0.000   0.000  273.21
#     9  124.21 -134.56    39.6   0.000   0.000   1.571  16.000   1.077   0.014   1.000  -0.000   0.000  256.94
#    10  -74.73 -144.16    53.2   0.000   0.000   1.571  16.000   1.077   0.014   1.000  -0.000   0.000  170.79
#    11 -214.79 -122.52    74.1   0.000   0.000   1.571  16.000   1.077   0.014   1.000  -0.000   0.000  205.43
#    12  -98.11  376.45    20.7   0.000   0.000   1.571  16.000   1.077   0.014   1.000  -0.000   0.000  351.74
#    13   21.08 -307.61    73.3   0.000   0.000   1.571  16.000   1.077   0.014   1.000  -0.000   0.000  348.76
#    14  -196.4 -290.24    88.1   0.000   0.000   1.571  16.000   1.077   0.014   1.000  -0.000   0.000  341.27
#    15     0.9   44.85    40.0   0.000   0.000   1.571  16.000   1.077   0.014   1.000  -0.000   0.000   79.27
#    16 -302.85   384.6     3.3   0.000   0.000   1.571  16.000   1.077   0.014   1.000  -0.000   0.000  426.47
#    17  -345.0   175.0    69.0   0.000   0.000   1.571  16.000   1.077   0.014   1.000  -0.000   0.000  308.14
#    18 -374.99  -33.39    92.6   0.000   0.000   1.571  16.000   1.077   0.014   1.000  -0.000   0.000  308.33
#    19  204.28 -267.84    53.0   0.000   0.000   1.571  16.000   1.077   0.014   1.000  -0.000   0.000  406.31

# %% [markdown]
# ## Activate the divergent pointing mode

# %%
array.divergent_pointing(div = 0.0043, az = 180, alt = 70)

#array.set_pointing_coord(az=180, alt=70)
#array.divergent_pointing(0.01)

# %% [markdown]
# ## Check the average of the telescope array location

# %%
array.calc_mean(["x", "y", "z"])
# Out:
# array([-75.7       ,  26.57684211,  49.07894737])

# %% [markdown]
# ## Check the average of the telescope pointing vector

# %%
array.calc_mean(["p_x", "p_y", "p_z"])
# Out:
# array([-3.42399044e-01,  1.26926972e-05,  9.39469241e-01])

# %% [markdown]
# ## Check the hyper field of view (hFoV)

# %%
array.hFoV(m_cut=3)
# Out:
# <Quantity 75.53508452 deg2>

# %% [markdown]
# ## Convert (radians or meters) to degrees

# %%
array.table.units = "deg"
array.table
# Out:
# <Table length=19>
#   id     x       y       z       az     alt      zn    focal   radius   fov     p_x     p_y     p_z    d_tel
#          m       m       m      deg     deg     deg      m      deg     deg2                             m
# int64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64
# ----- ------- ------- ------- ------- ------- ------- ------- ------- ------- ------- ------- ------- -------
#     1  -70.04   -7.23    54.0 180.244  70.017  19.983  28.000   2.150  14.536  -0.342   0.001   0.940   34.63
#     2  -34.37  110.98    43.0 179.389  70.090  19.910  28.000   2.150  14.536  -0.341  -0.004   0.940   94.18
#     3   76.18   95.34    39.7 179.495  70.344  19.656  28.000   2.150  14.536  -0.336  -0.003   0.942  166.98
#     4   31.81   -19.7    43.0 180.338  70.244  19.756  28.000   2.150  14.536  -0.338   0.002   0.941  117.20
#     5 -210.65   50.51    61.3 179.830  69.699  20.301  16.000   3.850  46.707  -0.347  -0.001   0.938  137.60
#     6 -179.06  223.02    42.1 178.603  69.750  20.250  16.000   3.850  46.707  -0.346  -0.008   0.938  222.09
#     7   27.96  243.56    23.2 178.417  70.212  19.788  16.000   3.850  46.707  -0.338  -0.009   0.941  241.86
#     8  176.27   127.9    19.3 179.246  70.559  19.441  16.000   3.850  46.707  -0.333  -0.004   0.943  273.21
#     9  124.21 -134.56    39.6 181.191  70.452  19.548  16.000   3.850  46.707  -0.335   0.007   0.942  256.94
#    10  -74.73 -144.16    53.2 181.230  70.001  19.999  16.000   3.850  46.707  -0.342   0.007   0.940  170.79
#    11 -214.79 -122.52    74.1 181.055  69.697  20.303  16.000   3.850  46.707  -0.347   0.006   0.938  205.43
#    12  -98.11  376.45    20.7 177.488  69.906  20.094  16.000   3.850  46.707  -0.343  -0.015   0.939  351.74
#    13   21.08 -307.61    73.3 182.435  70.228  19.772  16.000   3.850  46.707  -0.338   0.014   0.941  348.76
#    14  -196.4 -290.24    88.1 182.247  69.740  20.260  16.000   3.850  46.707  -0.346   0.014   0.938  341.27
#    15     0.9   44.85    40.0 179.867  70.170  19.830  16.000   3.850  46.707  -0.339  -0.001   0.941   79.27
#    16 -302.85   384.6     3.3 177.494  69.418  20.582  16.000   3.850  46.707  -0.351  -0.015   0.936  426.47
#    17  -345.0   175.0    69.0 178.966  69.393  20.607  16.000   3.850  46.707  -0.352  -0.006   0.936  308.14
#    18 -374.99  -33.39    92.6 180.416  69.347  20.653  16.000   3.850  46.707  -0.353   0.003   0.936  308.33
#    19  204.28 -267.84    53.0 182.197  70.641  19.359  16.000   3.850  46.707  -0.331   0.013   0.943  406.31

# %% [markdown]
# ## Check the ICRS coordinate of the pointing

# %%
array.frame.info
array.get_pointing_coord(icrs=True)
# Out:
# Observer         :  CTA North
# Location         :  Roque de los Muchachos , (5327.28509212, -1718.7771125, 3051.78673275) km
# Observation time :  2022-02-04T15:50:53.823
# <SkyCoord (ICRS): (ra, dec) in deg
#     [(354.27389994, 8.65805679), (354.56870376, 8.73132398),
#      (354.5301699 , 8.98531323), (354.24259068, 8.88501684),
#      (354.41750061, 8.33941727), (354.84664501, 8.39552592),
#      (354.90056781, 8.85900614), (354.61237463, 9.20160362),
#      (353.95489366, 9.09698579), (353.93274708, 8.64638299),
#      (353.98796146, 8.34072427), (355.23041601, 8.56375811),
#      (353.52459277, 8.88463527), (353.57180723, 8.39449119),
#      (354.40379617, 8.81071726), (355.24740599, 8.07605782),
#      (354.72548504, 8.03680209), (354.20971451, 7.98866667),
#      (353.62049237, 9.29423832)]>

# %% [markdown]
# ## Grouping telescopes

# %%
group = {"LST": [1,2,3,4],
        "MST": np.arange(5, 20)}

sub_groups={'1': [5,17,18], 
            '2': [10,11,14],
            '3': [7,15,8], 
            '4': [9,13,19],
            '5': [6,12,16],
            'LST': [1,2,3,4]}

array.display("xz", group=group)
# Out:
# <img src="data:image/png;base64,..." width="800">
# <AxesSubplot:xlabel='x [m]', ylabel='z [m]'>

# %% [markdown]
# ### Subarray barycenter

# %%
from ctadiv.ArrayConfig import visualization as visual

# %%
groupped_table, labels = array.group_by(sub_groups)
visual.display_barycenter(groupped_table, proj="xz", labels=labels)
# Out:
# <img src="data:image/png;base64,..." width="800">
# No handles with labels found to put in legend.
# <AxesSubplot:xlabel='x [m]', ylabel='z [m]'>

# %% [markdown]
# ## Export cfg file

# %%
array.export_cfg(verbose=True)
# Out:
# #ifndef TELESCOPE
#
# #  define TELESCOPE 0
#
# #endif
#
# #if TELESCOPE == 0
#
#    TELESCOPE_THETA=20.00
#
#    TELESCOPE_PHI=180.00
#
#
#
# % Global and default configuration for things missing in telescope-specific config.
#
# #  include <CTA-ULTRA6-LST.cfg>
#
#
#
# #elif TELESCOPE == 1
#
# #  include <CTA-ULTRA6-LST.cfg>
#
#    TELESCOPE_THETA=19.98
#
#    TELESCOPE_PHI=180.24
#
#
#
# #elif TELESCOPE == 2
#
# #  include <CTA-ULTRA6-LST.cfg>
#
#    TELESCOPE_THETA=19.91
#
#    TELESCOPE_PHI=179.39
#
#
#
# #elif TELESCOPE == 3
#
# #  include <CTA-ULTRA6-LST.cfg>
#
#    TELESCOPE_THETA=19.66
#
#    TELESCOPE_PHI=179.50
#
#
#
# #elif TELESCOPE == 4
#
# #  include <CTA-ULTRA6-LST.cfg>
#
#    TELESCOPE_THETA=19.76
#
#    TELESCOPE_PHI=180.34
#
#
#
# #elif TELESCOPE == 5
#
# #  include <CTA-ULTRA6-MST-NectarCam.cfg>
#
#    TELESCOPE_THETA=20.30
#
#    TELESCOPE_PHI=179.83
#
#
#
# #elif TELESCOPE == 6
#
# #  include <CTA-ULTRA6-MST-NectarCam.cfg>
#
#    TELESCOPE_THETA=20.25
#
#    TELESCOPE_PHI=178.60
#
#
#
# #elif TELESCOPE == 7
#
# #  include <CTA-ULTRA6-MST-NectarCam.cfg>
#
#    TELESCOPE_THETA=19.79
#
#    TELESCOPE_PHI=178.42
#
#
#
# #elif TELESCOPE == 8
#
# #  include <CTA-ULTRA6-MST-NectarCam.cfg>
#
#    TELESCOPE_THETA=19.44
#
#    TELESCOPE_PHI=179.25
#
#
#
# #elif TELESCOPE == 9
#
# #  include <CTA-ULTRA6-MST-NectarCam.cfg>
#
#    TELESCOPE_THETA=19.55
#
#    TELESCOPE_PHI=181.19
#
#
#
# #elif TELESCOPE == 10
#
# #  include <CTA-ULTRA6-MST-NectarCam.cfg>
#
#    TELESCOPE_THETA=20.00
#
#    TELESCOPE_PHI=181.23
#
#
#
# #elif TELESCOPE == 11
#
# #  include <CTA-ULTRA6-MST-NectarCam.cfg>
#
#    TELESCOPE_THETA=20.30
#
#    TELESCOPE_PHI=181.06
#
#
#
# #elif TELESCOPE == 12
#
# #  include <CTA-ULTRA6-MST-NectarCam.cfg>
#
#    TELESCOPE_THETA=20.09
#
#    TELESCOPE_PHI=177.49
#
#
#
# #elif TELESCOPE == 13
#
# #  include <CTA-ULTRA6-MST-NectarCam.cfg>
#
#    TELESCOPE_THETA=19.77
#
#    TELESCOPE_PHI=182.44
#
#
#
# #elif TELESCOPE == 14
#
# #  include <CTA-ULTRA6-MST-NectarCam.cfg>
#
#    TELESCOPE_THETA=20.26
#
#    TELESCOPE_PHI=182.25
#
#
#
# #elif TELESCOPE == 15
#
# #  include <CTA-ULTRA6-MST-NectarCam.cfg>
#
#    TELESCOPE_THETA=19.83
#
#    TELESCOPE_PHI=179.87
#
#
#
# #elif TELESCOPE == 16
#
# #  include <CTA-ULTRA6-MST-NectarCam.cfg>
#
#    TELESCOPE_THETA=20.58
#
#    TELESCOPE_PHI=177.49
#
#
#
# #elif TELESCOPE == 17
#
# #  include <CTA-ULTRA6-MST-NectarCam.cfg>
#
#    TELESCOPE_THETA=20.61
#
#    TELESCOPE_PHI=178.97
#
#
#
# #elif TELESCOPE == 18
#
# #  include <CTA-ULTRA6-MST-NectarCam.cfg>
#
#    TELESCOPE_THETA=20.65
#
#    TELESCOPE_PHI=180.42
#
#
#
# #elif TELESCOPE == 19
#
# #  include <CTA-ULTRA6-MST-NectarCam.cfg>
#
#    TELESCOPE_THETA=19.36
#
#    TELESCOPE_PHI=182.20
#
# #else
#
#    Error Invalid telescope for CTA-ULTRA6 La Palma configuration.
#
# #endif
#
# trigger_telescopes = 2 % In contrast to Prod-3 South we apply loose stereo trigger immediately
#
# array_trigger = array_trigger_ultra6_diver-test.dat

# %% [markdown]
# ## Display the telescope pointing

# %% [markdown]
# ### Simple display

# %%
# 1D
array.display("y")
# Out:
# <img src="data:image/png;base64,..." width="800">
# <AxesSubplot:xlabel='y [m]'>

# %%
# 2D
array.display("xz", group=group)
# Out:
# <img src="data:image/png;base64,..." width="800">
# <AxesSubplot:xlabel='x [m]', ylabel='z [m]'>

# %%
# 3D
array.display("xyz", group=group)
# Out:
# <img src="data:image/png;base64,..." width="800">
# <Axes3DSubplot:xlabel='x [m]', ylabel='y [m]'>

# %%
# Skymap
array.display(skymap=True,)
# Out:
# <img src="data:image/png;base64,..." width="800">
# <PolarAxesSubplot:xlabel='$\\mathrm{}$', ylabel='$\\mathrm{}$'>

# %%
# Multiplicity plot
array.multiplicity_plot()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# Multiplicity plot
array.skymap_polar()
# Out:
# <img src="data:image/png;base64,..." width="800">
# No handles with labels found to put in legend.

# %% [markdown]
# ## Advanced display

# %% [markdown]
# ### Interactive

# %%
from ctadiv.ArrayConfig.visualization import *

# %%
new_array = interactive_polar(array, group=group, overwrite=False)
# Out:
# <img src="data:image/png;base64,..." width="800">
# HBox(children=(FloatLogSlider(value=0.0043, description='Divergence', max=0.0, min=-4.0, step=0.2), FloatSlide…
# Output()

# %%
interactive_multiplicity(array, overwrite=True)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# HBox(children=(FloatLogSlider(value=0.0043, description='Divergence', max=0.0, min=-4.0, step=0.2), FloatSlide…
# Output()

# %%
interactive_barycenter(array, "xy", group=sub_groups)
# Out:
# <img src="data:image/png;base64,..." width="800">
# HBox(children=(FloatLogSlider(value=0.0043, description='Divergence', max=0.0, min=-4.0, step=0.2), FloatSlide…
# Output()
